# %%
import pandas as pd
coal_df = pd.read_excel('Pandas/coalpublic2013.xls')
coal_df.head()
# Out:
#    Year  MSHA ID                       Mine Name Mine State Mine County  \
# 0  2013   103381            Tacoa Highwall Miner    Alabama        Bibb
# 1  2013   103404                Reid School Mine    Alabama      Blount
# 2  2013   100759  North River #1 Underground Min    Alabama     Fayette
# 3  2013   103246                      Bear Creek    Alabama    Franklin
# 4  2013   103451                     Knight Mine    Alabama    Franklin
#
#                           Mine Status    Mine Type  \
# 0  Active, men working, not producing      Surface
# 1               Permanently abandoned      Surface
# 2  Active, men working, not producing  Underground
# 3                              Active      Surface
# 4                              Active      Surface
#
#                    Company Type              Operation Type  \
# 0  Indepedent Producer Operator                   Mine only
# 1  Indepedent Producer Operator                   Mine only
# ...

# %%
coal_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1450 entries, 0 to 1449
# Data columns (total 16 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   Year                       1450 non-null   int64
#  1   MSHA ID                    1450 non-null   int64
#  2   Mine Name                  1450 non-null   object
#  3   Mine State                 1450 non-null   object
#  4   Mine County                1450 non-null   object
#  5   Mine Status                1450 non-null   object
#  6   Mine Type                  1450 non-null   object
#  7   Company Type               1450 non-null   object
#  8   Operation Type             1450 non-null   object
#  9   Operating Company          1450 non-null   object
#  10  Operating Company Address  1450 non-null   object
#  11  Union Code                 1450 non-null   object
#  12  Coal Supply Region         1450 non-null   object
# ...

# %%
coal_df["Production (short tons)"].describe()
# Out:
# count    1.450000e+03
# mean     6.792012e+05
# std      4.414922e+06
# min      0.000000e+00
# 25%      0.000000e+00
# 50%      3.060650e+04
# 75%      2.514752e+05
# max      1.110055e+08
# Name: Production (short tons), dtype: float64

# %%
print("Min: ",coal_df["Production (short tons)"].min())
print("Max: " ,coal_df["Production (short tons)"].max())
print("Sum: ",coal_df["Production (short tons)"].sum())
print("Mean: " ,coal_df["Production (short tons)"].mean())
# Out:
# Min:  0
# Max:  111005549
# Sum:  984841779
# Mean:  679201.2268965517

# %%
employees_df = pd.read_excel('Pandas/employee.xlsx')

# %%
employees_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 20 entries, 0 to 19
# Data columns (total 4 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   emp_id      20 non-null     int64
#  1   first_name  20 non-null     object
#  2   last_name   20 non-null     object
#  3   hire_date   20 non-null     datetime64[ns]
# dtypes: datetime64[ns](1), int64(1), object(2)
# memory usage: 768.0+ bytes

# %%
employees_df[employees_df["hire_date"].dt.year ==  2005]
# Out:
#     emp_id first_name last_name  hire_date
# 1      101      Neena   Kochhar 2005-09-21
# 5      105      David    Austin 2005-06-25
# 10     110       John      Chen 2005-09-28
# 11     111     Ismael   Sciarra 2005-09-30
# 16     116     Shelli     Baida 2005-12-24
# 17     117      Sigal    Tobias 2005-07-24

# %%
diamonds_df = pd.read_csv('https://raw.githubusercontent.com/mwaskom/seaborn-data/master/diamonds.csv')
diamonds_df.head()
# Out:
#    carat      cut color clarity  depth  table  price     x     y     z
# 0   0.23    Ideal     E     SI2   61.5   55.0    326  3.95  3.98  2.43
# 1   0.21  Premium     E     SI1   59.8   61.0    326  3.89  3.84  2.31
# 2   0.23     Good     E     VS1   56.9   65.0    327  4.05  4.07  2.31
# 3   0.29  Premium     I     VS2   62.4   58.0    334  4.20  4.23  2.63
# 4   0.31     Good     J     SI2   63.3   58.0    335  4.34  4.35  2.75

# %%
diamonds_df[(diamonds_df["x"] > 5) & (diamonds_df["y"] > 5) & (diamonds_df["z"] > 5)]
# Out:
#        carat        cut color clarity  depth  table  price     x      y      z
# 11778   1.83       Fair     J      I1   70.0   58.0   5083  7.34   7.28   5.12
# 13002   2.14       Fair     J      I1   69.4   57.0   5405  7.74   7.70   5.36
# 13118   2.15       Fair     J      I1   65.5   57.0   5430  8.01   7.95   5.23
# 13562   1.96       Fair     F      I1   66.6   60.0   5554  7.59   7.56   5.04
# 13757   2.22       Fair     J      I1   66.7   56.0   5607  8.04   8.02   5.36
# ...      ...        ...   ...     ...    ...    ...    ...   ...    ...    ...
# 27748   2.00  Very Good     G     SI1   63.5   56.0  18818  7.90   7.97   5.04
# 27749   2.29    Premium     I     VS2   60.8   60.0  18823  8.50   8.47   5.16
# 48410   0.51  Very Good     E     VS1   61.8   54.7   1970  5.12   5.15  31.80
# 49189   0.51      Ideal     E     VS1   61.8   55.0   2075  5.15  31.80   5.12
# 49905   0.50  Very Good     G    VVS1   63.7   58.0   2180  5.01   5.04   5.06
#
# ...

# %%
diamonds_df[(diamonds_df["cut"] == "Premium") | (diamonds_df["cut"] == "Ideal")]
# Out:
#        carat      cut color clarity  depth  table  price     x     y     z
# 0       0.23    Ideal     E     SI2   61.5   55.0    326  3.95  3.98  2.43
# 1       0.21  Premium     E     SI1   59.8   61.0    326  3.89  3.84  2.31
# 3       0.29  Premium     I     VS2   62.4   58.0    334  4.20  4.23  2.63
# 11      0.23    Ideal     J     VS1   62.8   56.0    340  3.93  3.90  2.46
# 12      0.22  Premium     F     SI1   60.4   61.0    342  3.88  3.84  2.33
# ...      ...      ...   ...     ...    ...    ...    ...   ...   ...   ...
# 53931   0.71  Premium     F     SI1   59.8   62.0   2756  5.74  5.73  3.43
# 53934   0.72  Premium     D     SI1   62.7   59.0   2757  5.69  5.73  3.58
# 53935   0.72    Ideal     D     SI1   60.8   57.0   2757  5.75  5.76  3.50
# 53938   0.86  Premium     H     SI2   61.0   58.0   2757  6.15  6.12  3.74
# 53939   0.75    Ideal     D     SI2   62.2   55.0   2757  5.83  5.87  3.64
#
# [35342 rows x 10 columns]
